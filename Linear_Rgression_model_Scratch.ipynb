# %% [markdown]
# <a href="https://colab.research.google.com/github/Abishek-077/100-days-of-Python-projects/blob/main/Linear_Rgression_model_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Implementation for Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as ax
from matplotlib.animation import FuncAnimation

# %% [markdown]
# Loading the dataset

# %%
url = 'https://media.geeksforgeeks.org/wp-content/uploads/20240320114716/data_for_lr.csv'
data = pd.read_csv(url)
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %% [markdown]
# Cleaning and Preparing the Data

# %%
# Dropping the missing values
data = data.dropna()

#training the dataset and labels
X_train = np.array(data.x[0:500]).reshape(500, 1)
y_train = np.array(data.y[0:500]).reshape(500, 1)

# Testing the data set
X_test = np.array(data.x[500:700]).reshape(199, 1)
y_test = np.array(data.y[500:700]).reshape(199,1)

# %% [markdown]
# Making a  linear regression model with modular function which can be optimized accordingly

# %%
class LinearRegression:
  def __init__(self): # basically oop concpt for constructor
    self.parameters ={}

    def forward_progagation(self, train_input):
      m =self.parameters['m']
      c = self.parameters['c']
      predictions = np.multiply(m,train_input)+c # y = mx+c
      return predictions

    def cost_function(self, predictions, train_output):
      cost = np.mean(np.square(predictions -train_output))
      return cost

    def back_propagation(self,prediction, train_input, train_output):
      dervatives ={}
      m_deriv = -2*np.mean(X_train(y_train - predictions))
      c_deriv = -2*np.mean(y_train - predictions)

      derivatives ['m_deriv'] =m_deriv
      derivatives['c_deriv'] = c_deriv

      return derivatives

    def update_parameters(self,derivatives,learning_rates):
      self_parameters['m'] -= learning_rate * derivatives['m_deriv']
      self_parameters['c'] -= learning_rate * derivatives['c_deriv']

    def train(self, train_input,train_output, learning_rate, epochs):
      for epoch in range(epochs):
        # Initilize random parameters
        self.parameters['m'] = np.random.uniform(0,1)*-1
        self.parameters['c'] = np.random.uniform(0.1)*-1

        #Initlize loss
        self.loss=[]

        fig, ax =plt.subplots()
        x_vals =np.linspace(min(train_input),max(train_input),100)
        line, =ax.plot(x_vals,self.parameters['m']*x_vals+self.parameters['c'], color='red', label='Regression model Line')

        ax.scatter(train_input, train_output, maker='o', color='green', label ='Traning Data')

        # Set y-axis limits to exclude negative valyes
        ax.set_ylim(0,max(y_train)+1)

        def update(frame):
          predictions = self.forward_progagation(X_train)

          cost =sele.cost_function(predictions, y_train)

          derivatives = self.back_propagation(predictions, X_train, y_train)

          self.update_parameters(derivatives,learning_rate)

          line.set_ydata(self.parameters['m']*x_vals+self.parameters['c'])
          self.loss.append(cost)
          print("Iteration ={}, loss ={}".format(frame+1),cost)

          return line,

          ani = FuncAnimation(fig,update, frames=iters, interval=200, blit=true)

          plt.xlabel('Input')
          plt.ylabel('Output')
          plt.title('linear regression model')
          plt.legend()
          plt.show()
